# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu29093-hub/Bhuvanchandu/blob/main/bhuvan_use_case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def roll_dice(num_dice, num_sides):
  """
  Simulates rolling a number of dice with a given number of sides.

  Args:
    num_dice: The number of dice to roll.     num_sides: The number of sides on each die.

  Returns:
    A numpy array containing the result of each dice roll.
  """   return np.random.randint(1, num_sides + 1, size=num_dice) if __name__ == "__main__":   print("Dice Rolling Simulator")

  while True:     try:
      num_dice_to_roll = int(input("Enter the number of dice to roll: "))       if num_dice_to_roll <= 0:
        print("Please enter a positive number of dice.")         continue

      num_sides_on_dice = int(input("Enter the number of sides on each die: "))       if num_sides_on_dice <= 1:
        print("A die must have at least 2 sides.")         continue

      rolls = roll_dice(num_dice_to_roll, num_sides_on_dice)

      print("\n--- Results ---")       print(f"You rolled {num_dice_to_roll} dice with {num_sides_on_dice} sides each.")       print(f"Individual rolls: {rolls}")       print(f"Sum of rolls: {np.sum(rolls)}")       print(f"Average roll: {np.mean(rolls):.2f}")       print("---------------")

    except ValueError:
      print("Invalid input. Please enter a valid number.")

    rerun = input("\nRoll again? (yes/no): ").lower()     if rerun != 'yes':
      print("Thanks for rolling!")       break
